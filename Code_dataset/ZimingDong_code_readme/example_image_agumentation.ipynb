# %%
from visual_genome import api
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from PIL import Image 
import requests
try:
    from StringIO import StringIO ## for Python 2
except ImportError:
    from io import StringIO ## for Python 3
from io import StringIO, BytesIO
import pandas as pd
import json
from PIL import Image, ImageOps
import imageio

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.1

# %%
# with open('V1.4/relationships.json') as f:
#      relations4= json.load(f) 
# relations4[0]

# %%
# with open('V1.4/relationship_synsets.json') as f:
#      relations4_synsets= json.load(f) 
# relations4_synsets

# %%
with open('V1.0/relationships.json') as f:
     relations= json.load(f)

# %%
relations[3]['relationships']
# Out:
# [{'predicate': 'have',
#   'object': {'name': 'curtains',
#    'h': 300,
#    'w': 280,
#    'y': 1,
#    'x': 360,
#    'id': 38336},
#   'id': 15996,
#   'subject': {'name': 'curtains',
#    'h': 300,
#    'w': 280,
#    'y': 1,
#    'x': 360,
#    'id': 38336}},
#  {'predicate': 'has',
#   'object': {'name': 'padding',
#    'h': 27,
#    'w': 72,
#    'y': 284,
#    'x': 407,
#    'id': 38338},
#   'id': 15997,
#   'subject': {'name': 'chair',
#    'h': 157,
#    'w': 92,
#    'y': 214,
#    'x': 387,
#    'id': 38337}},
#  {'predicate': 'on',
#   'object': {'name': 'floor',
#    'h': 188,
#    'w': 631,
#    'y': 290,
#    'x': 1,
#    'id': 38341},
#   'id': 15998,
#   'subject': {'name': 'carpet',
#    'h': 157,
#    'w': 629,
#    'y': 321,
#    'x': 2,
#    'id': 38340}},
#  {'predicate': 'on',
#   'object': {'name': 'couch',
#    'h': 172,
#    'w': 260,
#    'y': 210,
#    'x': 105,
#    'id': 38344},
#   'id': 15999,
#   'subject': {'name': 'pillow',
#    'h': 86,
# ...

# %%
#image_id
relations[999]['id']
# Out:
# 1000

# %%
image = api.get_image_data(id=2368)
image_url=image.url
image=imageio.imread(image_url)
ia.imshow(image)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

im = image

# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(im)

# # Create a Rectangle patch
rect1 = patches.Rectangle((1,185),494,41,linewidth=1,edgecolor='r',facecolor='none')
rect2 = patches.Rectangle((7,233),498,159,linewidth=1,edgecolor='r',facecolor='none')
# # Add the patch to the Axes
ax.add_patch(rect1)
ax.add_patch(rect2)

plt.show()

# %%
relation=relations[0]['relationships'][1]['predicate']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-7eb509f896ea> in <module>
# ----> 1 relation=relations[0]['relationships'][1]['predicate']
#
# NameError: name 'relations' is not defined

# %%
object_name=relations[0]['relationships'][1]['object']['name']
Xmin1,Ymin1=relations[0]['relationships'][1]['object']['x'],relations[0]['relationships'][1]['object']['y']
Xmax1=relations[0]['relationships'][1]['object']['x']+relations[0]['relationships'][1]['object']['w']
Ymax1=relations[0]['relationships'][1]['object']['y']+relations[0]['relationships'][1]['object']['h']

subject_name=relations[0]['relationships'][1]['subject']['name']
Xmin2,Ymin2=relations[0]['relationships'][1]['subject']['x'],relations[0]['relationships'][1]['subject']['y']
Xmax2=relations[0]['relationships'][1]['subject']['x']+relations[0]['relationships'][1]['subject']['w']
Ymax2=relations[0]['relationships'][1]['subject']['y']+relations[0]['relationships'][1]['subject']['h']

# %%
object_name,Xmin1,Ymin1,Xmax1,Ymax1
# Out:
# ('sneakers', 243, 489, 295, 515)

# %%
subject_name,Xmin2,Ymin2,Xmax2,Ymax2
# Out:
# ('man', 238, 249, 298, 511)

# %%
relationship=str(subject_name+' '+relation+' '+object_name)
relationship
# Out:
# 'man wears sneakers'

# %%
relations[1]
# Out:
# {'relationships': [{'predicate': 'wears',
#    'object': {'name': 'backpack',
#     'h': 81,
#     'w': 72,
#     'y': 362,
#     'x': 359,
#     'id': 38246},
#    'id': 15947,
#    'subject': {'name': 'man',
#     'h': 255,
#     'w': 142,
#     'y': 320,
#     'x': 324,
#     'id': 38247}},
#   {'predicate': 'parked on',
#    'object': {'name': 'road',
#     'h': 279,
#     'w': 372,
#     'y': 321,
#     'x': 3,
#     'id': 38249},
#    'id': 15948,
#    'subject': {'name': 'car',
#     'h': 126,
#     'w': 136,
#     'y': 347,
#     'x': 239,
#     'id': 38248}},
#   {'predicate': 'next to',
#    'object': {'name': 'road',
#     'h': 279,
#     'w': 372,
#     'y': 321,
#     'x': 3,
#     'id': 38253},
#    'id': 15949,
#    'subject': {'name': 'tree',
#     'h': 223,
#     'w': 73,
#     'y': 146,
#     'x': 0,
#     'id': 38250}},
#   {'predicate': 'next to',
#    'object': {'name': 'road',
#     'h': 279,
#     'w': 372,
#     'y': 321,
#     'x': 3,
#     'id': 38253},
# ...

# %% [markdown]
# #  Image Augmentation

# %%
import imageio
import imgaug as ia
# %matplotlib inline

# %%
image=imageio.imread(image_url)
regions = api.get_region_descriptions_of_image(id=1)

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
def visualize_regions(image, regions):
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    plt.imshow(img)
    ax = plt.gca()
    for region in regions:
        ax.add_patch(Rectangle((region.x, region.y),
                               region.width,
                               region.height,
                               fill=False,
                               edgecolor='red',
                               linewidth=3))
        ax.text(region.x, region.y, region.phrase, style='italic', bbox={'facecolor':'white', 'alpha':0.7, 'pad':10})
    fig = plt.gcf()
    plt.tick_params(labelbottom='off', labelleft='off')
    plt.show()
visualize_regions(image, regions[:5])

# %% [markdown]
# ### Method 1: Flip image

# %%
import imageio
image=imageio.imread(image_url)

# %%
import imgaug.augmenters as iaa
flip=iaa.Fliplr(1.0)
image_aug=flip(image=image)
ia.imshow(image_aug)

# %%
object_name,Xmin1,Ymin1,Xmax1,Ymax1
# Out:
# ('sneakers', 243, 489, 295, 515)

# %%
width=800
height=600

# %%
new_Xmax1=800-Xmin1
new_Xmin1=800-Xmax1
new_Xmin1,new_Xmax1
# Out:
# (505, 557)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

im = np.array(Image.open('image_augmentation/new1.jpg'), dtype=np.uint8)

# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(im)

# Create a Rectangle patch
rect = patches.Rectangle((new_Xmin1,Ymin1),52,26,linewidth=1,edgecolor='r',facecolor='none')
# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %%
new_Xmax2=800-Xmin2
new_Xmin2=800-Xmax2
new_Xmin2,new_Xmax2
# Out:
# (502, 562)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

im = np.array(Image.open('image_augmentation/new1.jpg'), dtype=np.uint8)

# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(im)

# Create a Rectangle patch
rect1 = patches.Rectangle((new_Xmin2,Ymin2),60,262,linewidth=1,edgecolor='r',facecolor='none')
rect2 = patches.Rectangle((new_Xmin1,Ymin1),52,26,linewidth=1,edgecolor='r',facecolor='none')
# Add the patch to the Axes
ax.add_patch(rect1)
ax.add_patch(rect2)

plt.show()
